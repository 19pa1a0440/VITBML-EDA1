# %% [markdown]
# <a href="https://colab.research.google.com/github/19pa1a0440/VITBML-EDA1/blob/master/ai_assaignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn import metrics

# %%
pop=pd.read_csv("sonar.all-data")
print(pop)
# Out:
#      0.0200  0.0371  0.0428  0.0207  0.0954  ...  0.0180  0.0084  0.0090  0.0032  R
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  ...  0.0140  0.0049  0.0052  0.0044  R
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  ...  0.0316  0.0164  0.0095  0.0078  R
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  ...  0.0050  0.0044  0.0040  0.0117  R
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  ...  0.0072  0.0048  0.0107  0.0094  R
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  ...  0.0057  0.0027  0.0051  0.0062  R
# ..      ...     ...     ...     ...     ...  ...     ...     ...     ...     ... ..
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  ...  0.0065  0.0115  0.0193  0.0157  M
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  ...  0.0034  0.0032  0.0062  0.0067  M
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  ...  0.0140  0.0138  0.0077  0.0031  M
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  ...  0.0034  0.0079  0.0036  0.0048  M
# ...

# %%
pop.head()
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  ...  0.0180  0.0084  0.0090  0.0032  R
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  ...  0.0140  0.0049  0.0052  0.0044  R
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  ...  0.0316  0.0164  0.0095  0.0078  R
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  ...  0.0050  0.0044  0.0040  0.0117  R
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  ...  0.0072  0.0048  0.0107  0.0094  R
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  ...  0.0057  0.0027  0.0051  0.0062  R
#
# [5 rows x 61 columns]

# %%
pop.tail()
# Out:
#      0.0200  0.0371  0.0428  0.0207  0.0954  ...  0.0180  0.0084  0.0090  0.0032  R
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  ...  0.0065  0.0115  0.0193  0.0157  M
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  ...  0.0034  0.0032  0.0062  0.0067  M
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  ...  0.0140  0.0138  0.0077  0.0031  M
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  ...  0.0034  0.0079  0.0036  0.0048  M
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  ...  0.0040  0.0036  0.0061  0.0115  M
#
# [5 rows x 61 columns]

# %%
pop.columns
# Out:
# Index(['0.0200', '0.0371', '0.0428', '0.0207', '0.0954', '0.0986', '0.1539',
#        '0.1601', '0.3109', '0.2111', '0.1609', '0.1582', '0.2238', '0.0645',
#        '0.0660', '0.2273', '0.3100', '0.2999', '0.5078', '0.4797', '0.5783',
#        '0.5071', '0.4328', '0.5550', '0.6711', '0.6415', '0.7104', '0.8080',
#        '0.6791', '0.3857', '0.1307', '0.2604', '0.5121', '0.7547', '0.8537',
#        '0.8507', '0.6692', '0.6097', '0.4943', '0.2744', '0.0510', '0.2834',
#        '0.2825', '0.4256', '0.2641', '0.1386', '0.1051', '0.1343', '0.0383',
#        '0.0324', '0.0232', '0.0027', '0.0065', '0.0159', '0.0072', '0.0167',
#        '0.0180', '0.0084', '0.0090', '0.0032', 'R'],
#       dtype='object')

# %%
x=pop[['0.0200','0.0371']]
y=pop[['0.3109','0.2111']]

# %%
x
# Out:
#      0.0200  0.0371
# 0    0.0453  0.0523
# 1    0.0262  0.0582
# 2    0.0100  0.0171
# 3    0.0762  0.0666
# 4    0.0286  0.0453
# ..      ...     ...
# 202  0.0187  0.0346
# 203  0.0323  0.0101
# 204  0.0522  0.0437
# 205  0.0303  0.0353
# 206  0.0260  0.0363
#
# [207 rows x 2 columns]

# %%
y
# Out:
#      0.3109  0.2111
# 0    0.3337  0.2872
# 1    0.5598  0.6194
# 2    0.0598  0.1264
# 3    0.3564  0.4459
# 4    0.2105  0.3039
# ..      ...     ...
# 202  0.2328  0.2684
# 203  0.1030  0.2154
# 204  0.1258  0.2529
# 205  0.1945  0.2354
# 206  0.1843  0.2354
#
# [207 rows x 2 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=0)

# %%
x_train.head
# Out:
# <bound method NDFrame.head of      0.0200  0.0371
# 104  0.0116  0.0179
# 193  0.0392  0.0108
# 4    0.0286  0.0453
# 74   0.0202  0.0104
# 135  0.1088  0.1278
# ..      ...     ...
# 67   0.0195  0.0142
# 192  0.0203  0.0121
# 117  0.0363  0.0478
# 47   0.0190  0.0038
# 172  0.0329  0.0216
#
# [165 rows x 2 columns]>

# %%
y_train.head
# Out:
# <bound method NDFrame.head of      0.3109  0.2111
# 104  0.0757  0.1006
# 193  0.2105  0.2471
# 4    0.2105  0.3039
# 74   0.1317  0.1370
# 135  0.6828  0.5761
# ..      ...     ...
# 67   0.0840  0.1191
# 192  0.1136  0.1747
# 117  0.1703  0.1444
# 47   0.0740  0.0349
# 172  0.2532  0.2672
#
# [165 rows x 2 columns]>

# %%
x_test
# Out:
#      0.0200  0.0371
# 12   0.0090  0.0062
# 80   0.0100  0.0194
# 33   0.0311  0.0491
# 5    0.0317  0.0956
# 162  0.0072  0.0027
# 83   0.0378  0.0318
# 116  0.0228  0.0106
# 122  0.0270  0.0163
# 90   0.0253  0.0808
# 131  0.0968  0.0821
# 45   0.0308  0.0339
# 155  0.0047  0.0059
# 52   0.0293  0.0378
# 188  0.0158  0.0239
# 96   0.0491  0.0279
# 86   0.0856  0.0454
# 191  0.0056  0.0267
# 37   0.0123  0.0022
# 66   0.0368  0.0403
# 18   0.0126  0.0149
# 169  0.0134  0.0172
# 15   0.0352  0.0116
# 7    0.0223  0.0375
# 55   0.0152  0.0102
# 92   0.0459  0.0437
# 157  0.0107  0.0453
# 125  0.0715  0.0849
# 124  0.0228  0.0853
# 153  0.0117  0.0069
# 183  0.0269  0.0383
# 75   0.0239  0.0189
# 181  0.0095  0.0308
# 137  0.0731  0.1249
# 71   0.0208  0.0186
# 185  0.0209  0.0191
# 144  0.0721  0.1574
# 178  0.0394  0.0420
# 118  0.0261  0.0266
# 16   0.0192  0.0607
# 134  0.0094  0.0611
# 146  0.0654  0.0649
# 22   0.0115  0.0150

# %%
pop.plot(style='o')

# %%
har=LinearRegression()
har.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
c=har.intercept_
c
# Out:
# array([0.10587669, 0.13359507])

# %%
m=har.coef_
m
# Out:
# array([[1.85562173, 0.24965531],
#        [1.82856758, 0.33431944]])

# %%
mine=har.predict(x_test)
mine
# Out:
# array([[0.12412515, 0.15212496],
#        [0.12927622, 0.15836654],
#        [0.1758446 , 0.2068786 ],
#        [0.18856694, 0.2235216 ],
#        [0.11991123, 0.14766342],
#        [0.18395823, 0.21334628],
#        [0.15083121, 0.1788302 ],
#        [0.16004785, 0.1884158 ],
#        [0.17299607, 0.20687084],
#        [0.30599757, 0.33804804],
#        [0.17149315, 0.20124838],
#        [0.11607108, 0.14416182],
#        [0.16968337, 0.19980937],
#        [0.14116227, 0.17047667],
#        [0.2039531 , 0.23270525],
#        [0.27605226, 0.30529856],
#        [0.12293397, 0.15276138],
#        [0.12925008, 0.15682195],
#        [0.18422468, 0.21435943],
#        [0.13297738, 0.16161638],
#        [0.13503609, 0.16384817],
#        [0.17409057, 0.20183875],
#        [0.15661913, 0.1869091 ],
#        [0.13662862, 0.16479935],
#        [0.20195966, 0.23213608],
#        [0.13704122, 0.16830541],
#        [0.25974938, 0.29272137],
#        [0.16948046, 0.20380386],
# ...

# %%
plt.scatter(x_test,y_test,color='green')
plt.plot(x_test,mine,color="yellow")
plt.xlabel("purple")
plt.ylabel("grey")
# Out:
# Text(0, 0.5, 'grey')

# %%
pop.isna().any()
# Out:
# 0.0200    False
# 0.0371    False
# 0.0428    False
# 0.0207    False
# 0.0954    False
#           ...
# 0.0180    False
# 0.0084    False
# 0.0090    False
# 0.0032    False
# R         False
# Length: 61, dtype: bool

# %%
pop=pop.fillna(method='ffill')
pop.isna().any()
# Out:
# 0.0200    False
# 0.0371    False
# 0.0428    False
# 0.0207    False
# 0.0954    False
#           ...
# 0.0180    False
# 0.0084    False
# 0.0090    False
# 0.0032    False
# R         False
# Length: 61, dtype: bool

# %% [markdown]
# decision classifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## **svm**,**svc**

# %%
from sklearn import svm, datasets

# %%
iris = datasets.load_iris()
X = iris.data[:, :2] # we only take the first two features. We could
 # avoid this ugly slicing by using a two-dim dataset
y = iris.target

# %%
C = 1.0 # SVM regularization parameter
svc = svm.SVC(kernel='linear', C=1,gamma=1).fit(X, y)

# %%
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
h = (x_max / x_min)/100
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
 np.arange(y_min, y_max, h))

# %%
plt.subplot(1, 1, 1)
Z = svc.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, cmap=plt.cm.Paired, alpha=0.5)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.xlim(xx.min(), xx.max())
plt.title('SVC with linear kernel')
plt.show()

# %%
plt.scatter(X[:, 1], X[:, 0], c=y, cmap=plt.cm.Paired)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.xlim(xx.min(), xx.max())
plt.title('SVC with linear kernel')
plt.show()

# %%
C = 1 # SVM regularization parameter
svc = svm.SVC(kernel='linear', C=1,gamma=1000).fit(X, y)

# %%
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
h = (x_max / x_min)/100
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
 np.arange(y_min, y_max, h))

# %%
plt.subplot(5, 1, 5)
Z = svc.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, cmap=plt.cm.Paired, alpha=0.8)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.xlim(xx.min(), xx.max())
plt.title('SVC with linear kernel')
plt.show()

# %% [markdown]
# ##**confusion matrix,kNN**
#
# > Indented block

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report

# %%
actual = [1, 0, 0, 1, 0, 0, 1, 0, 1, 0] 
predicted = [1, 0, 0, 1, 0, 0, 1, 1, 1, 0] 
results = confusion_matrix(actual, predicted)

# %%
print('Confusion Matrix')
print(results) 
print ('Accuracy Score',accuracy_score(actual, predicted)) 
print('Report')
print(classification_report(actual, predicted))
# Out:
# Confusion Matrix
# [[5 1]
#  [0 4]]
# Accuracy Score 0.9
# Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91         6
#            1       0.80      1.00      0.89         4
#
#     accuracy                           0.90        10
#    macro avg       0.90      0.92      0.90        10
# weighted avg       0.92      0.90      0.90        10

# %%
pop.columns
# Out:
# Index(['0.0200', '0.0371', '0.0428', '0.0207', '0.0954', '0.0986', '0.1539',
#        '0.1601', '0.3109', '0.2111', '0.1609', '0.1582', '0.2238', '0.0645',
#        '0.0660', '0.2273', '0.3100', '0.2999', '0.5078', '0.4797', '0.5783',
#        '0.5071', '0.4328', '0.5550', '0.6711', '0.6415', '0.7104', '0.8080',
#        '0.6791', '0.3857', '0.1307', '0.2604', '0.5121', '0.7547', '0.8537',
#        '0.8507', '0.6692', '0.6097', '0.4943', '0.2744', '0.0510', '0.2834',
#        '0.2825', '0.4256', '0.2641', '0.1386', '0.1051', '0.1343', '0.0383',
#        '0.0324', '0.0232', '0.0027', '0.0065', '0.0159', '0.0072', '0.0167',
#        '0.0180', '0.0084', '0.0090', '0.0032', 'R'],
#       dtype='object')

# %% [markdown]
# #**DECISION** TREE CLASSIFIER

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
a=pop[['0.0200','0.0428','0.0207']]
b=pop.R

# %%
a
# Out:
#      0.0200  0.0428  0.0207
# 0    0.0453  0.0843  0.0689
# 1    0.0262  0.1099  0.1083
# 2    0.0100  0.0623  0.0205
# 3    0.0762  0.0481  0.0394
# 4    0.0286  0.0277  0.0174
# ..      ...     ...     ...
# 202  0.0187  0.0168  0.0177
# 203  0.0323  0.0298  0.0564
# 204  0.0522  0.0180  0.0292
# 205  0.0303  0.0490  0.0608
# 206  0.0260  0.0136  0.0272
#
# [207 rows x 3 columns]

# %%
b
# Out:
# 0      R
# 1      R
# 2      R
# 3      R
# 4      R
#       ..
# 202    M
# 203    M
# 204    M
# 205    M
# 206    M
# Name: R, Length: 207, dtype: object

# %%
a_train,a_test,b_train,b_test=train_test_split(a,b,test_size=0.2,random_state=100)

# %%
a_train
# Out:
#      0.0200  0.0428  0.0207
# 127  0.0374  0.0628  0.0534
# 85   0.0188  0.0953  0.0824
# 32   0.0442  0.0049  0.0581
# 175  0.0635  0.0453  0.0333
# 26   0.0177  0.0288  0.0394
# ..      ...     ...     ...
# 87   0.0274  0.0621  0.0560
# 103  0.0307  0.0653  0.0521
# 67   0.0195  0.0181  0.0406
# 24   0.0201  0.0138  0.0062
# 8    0.0164  0.0347  0.0070
#
# [165 rows x 3 columns]

# %%
b_train
# Out:
# 127    M
# 85     R
# 32     R
# 175    M
# 26     R
#       ..
# 87     R
# 103    M
# 67     R
# 24     R
# 8      R
# Name: R, Length: 165, dtype: object

# %%
a_test
# Out:
#      0.0200  0.0428  0.0207
# 162  0.0072  0.0089  0.0061
# 188  0.0158  0.0150  0.0494
# 59   0.0130  0.0088  0.0456
# 81   0.0409  0.0573  0.0130
# 189  0.0156  0.0282  0.0596
# 64   0.0176  0.0501  0.0285
# 161  0.0217  0.0346  0.0346
# 124  0.0228  0.1000  0.0428
# 174  0.0294  0.0117  0.0113
# 136  0.0430  0.0833  0.0813
# 88   0.0235  0.0749  0.0519
# 179  0.0310  0.0433  0.0191
# 112  0.0283  0.0656  0.0229
# 41   0.0211  0.0415  0.0286
# 74   0.0202  0.0325  0.0239
# 31   0.0195  0.0058  0.0190
# 157  0.0107  0.0289  0.0713
# 134  0.0094  0.1136  0.1203
# 65   0.0265  0.0137  0.0084
# 177  0.0197  0.0384  0.0076
# 185  0.0209  0.0411  0.0321
# 139  0.0412  0.0518  0.0232
# 115  0.0094  0.0306  0.0376
# 125  0.0715  0.0587  0.0218
# 169  0.0134  0.0178  0.0363
# 165  0.0411  0.0604  0.0525
# 120  0.0162  0.0239  0.0441
# 69   0.0065  0.0068  0.0108
# 11   0.0079  0.0055  0.0250
# 46   0.0373  0.0232  0.0225
# 186  0.0368  0.0103  0.0566
# 15   0.0352  0.0191  0.0469
# ...

# %%
b_test
# Out:
# 162    M
# 188    M
# 59     R
# 81     R
# 189    M
# 64     R
# 161    M
# 124    M
# 174    M
# 136    M
# 88     R
# 179    M
# 112    M
# 41     R
# 74     R
# 31     R
# 157    M
# 134    M
# 65     R
# 177    M
# 185    M
# 139    M
# 115    M
# 125    M
# 169    M
# 165    M
# 120    M
# 69     R
# 11     R
# 46     R
# 186    M
# 15     R
# 111    M
# 104    M
# 99     M
# 142    M
# 171    M
# 200    M
# 184    M
# 101    M
# 75     R
# 3      R
# Name: R, dtype: object

# %%
clf = DecisionTreeClassifier()
clf
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
clf = clf.fit(a_train,b_train)

# %%
b_pred = clf.predict(a_test)

# %%
print('Accuracy',metrics.accuracy_score(b_test, b_pred))
# Out:
# Accuracy 0.35714285714285715

# %%
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

# %%
dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names =(['0.0201','0.0428','0.2111']),class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('diabetes.png')
Image(graph.create_png())
